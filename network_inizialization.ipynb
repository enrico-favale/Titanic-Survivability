# %%
# %reload_ext autoreload
# %autoreload

import classes.NeuralNetwork as NeuralNetwork
import classes.NeuralNetworkAutoTuning as NeuralNetworkAutoTuning

import importlib

importlib.reload(NeuralNetwork)  # Reload module
importlib.reload(NeuralNetworkAutoTuning)  # Reload module

from classes.NeuralNetwork import TitanicSurvivalModel
from classes.NeuralNetworkAutoTuning import TitanicSurvivalModelAutoTuning

# %%
model = TitanicSurvivalModel(dataset_path = 'data/dataset.csv',
                             epochs = 37,
                             batch_size = 64,
                             test_split = 0.1,
                             validation_split = 0.2,
                             learning_rate = 5e-4,
                            )

model.start()
model.plot_all()
model.summarize()
# Out:
# ✅ Preprocessing completato!
# Features finali: ['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'Title', 'Has_Cabin', 'Family_Size', 'Is_Alone', 'Age_Group', 'Fare_Group']
# Epoch 1/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.5355 - f1_score: 0.5648 - loss: 0.8705 - precision: 0.4298 - val_accuracy: 0.6335 - val_f1_score: 0.5229 - val_loss: 0.6878 - val_precision: 0.4884
# Epoch 2/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5940 - f1_score: 0.5752 - loss: 0.7658 - precision: 0.4979 - val_accuracy: 0.7019 - val_f1_score: 0.5229 - val_loss: 0.6750 - val_precision: 0.5692
# Epoch 3/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6799 - f1_score: 0.5575 - loss: 0.6223 - precision: 0.5703 - val_accuracy: 0.7205 - val_f1_score: 0.5229 - val_loss: 0.6561 - val_precision: 0.6034
# Epoch 4/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6702 - f1_score: 0.5418 - loss: 0.6310 - precision: 0.5463 - val_accuracy: 0.7453 - val_f1_score: 0.5229 - val_loss: 0.6381 - val_precision: 0.6739
# Epoch 5/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7183 - f1_score: 0.5527 - loss: 0.5846 - precision: 0.6143 - val_accuracy: 0.7329 - val_f1_score: 0.5229 - val_loss: 0.6232 - val_precision: 0.6591
# Epoch 6/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7348 - f1_score: 0.5615 - loss: 0.6397 - precision: 0.6470 - val_accuracy: 0.7453 - val_f1_score: 0.5229 - val_loss: 0.6090 - val_precision: 0.6905
# Epoch 7/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7083 - f1_score: 0.5736 - loss: 0.6217 - precision: 0.6343 - val_accuracy: 0.7516 - val_f1_score: 0.5229 - val_loss: 0.5965 - val_precision: 0.7429
# Epoch 8/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7452 - f1_score: 0.5032 - loss: 0.5448 - precision: 0.5944 - val_accuracy: 0.7578 - val_f1_score: 0.5229 - val_loss: 0.5817 - val_precision: 0.8000
# Epoch 9/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7686 - f1_score: 0.5751 - loss: 0.5669 - precision: 0.6991 - val_accuracy: 0.7578 - val_f1_score: 0.5229 - val_loss: 0.5681 - val_precision: 0.8214
# Epoch 10/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7723 - f1_score: 0.5640 - loss: 0.5296 - precision: 0.6896 - val_accuracy: 0.7516 - val_f1_score: 0.5229 - val_loss: 0.5574 - val_precision: 0.8148
# Epoch 11/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7685 - f1_score: 0.5712 - loss: 0.5526 - precision: 0.6917 - val_accuracy: 0.7640 - val_f1_score: 0.5229 - val_loss: 0.5491 - val_precision: 0.8276
# Epoch 12/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7618 - f1_score: 0.5644 - loss: 0.5675 - precision: 0.6870 - val_accuracy: 0.7764 - val_f1_score: 0.5229 - val_loss: 0.5407 - val_precision: 0.8387
# Epoch 13/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7725 - f1_score: 0.5762 - loss: 0.5321 - precision: 0.7174 - val_accuracy: 0.7764 - val_f1_score: 0.5229 - val_loss: 0.5312 - val_precision: 0.8387
# Epoch 14/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7978 - f1_score: 0.5699 - loss: 0.4959 - precision: 0.7412 - val_accuracy: 0.7764 - val_f1_score: 0.5229 - val_loss: 0.5236 - val_precision: 0.8387
# Epoch 15/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7752 - f1_score: 0.5474 - loss: 0.5248 - precision: 0.6806 - val_accuracy: 0.7826 - val_f1_score: 0.5229 - val_loss: 0.5176 - val_precision: 0.8438
# Epoch 16/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7908 - f1_score: 0.5502 - loss: 0.5097 - precision: 0.7060 - val_accuracy: 0.7826 - val_f1_score: 0.5229 - val_loss: 0.5099 - val_precision: 0.8438
# Epoch 17/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7914 - f1_score: 0.5326 - loss: 0.4806 - precision: 0.6861 - val_accuracy: 0.7826 - val_f1_score: 0.5229 - val_loss: 0.4997 - val_precision: 0.8438
# Epoch 18/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7861 - f1_score: 0.5691 - loss: 0.5178 - precision: 0.7145 - val_accuracy: 0.7764 - val_f1_score: 0.5229 - val_loss: 0.4894 - val_precision: 0.8387
# Epoch 19/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7970 - f1_score: 0.5547 - loss: 0.5114 - precision: 0.7239 - val_accuracy: 0.7826 - val_f1_score: 0.5229 - val_loss: 0.4786 - val_precision: 0.8438
# Epoch 20/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7540 - f1_score: 0.5696 - loss: 0.5113 - precision: 0.6861 - val_accuracy: 0.7888 - val_f1_score: 0.5229 - val_loss: 0.4711 - val_precision: 0.8485
# Epoch 21/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7992 - f1_score: 0.5612 - loss: 0.4871 - precision: 0.7464 - val_accuracy: 0.7950 - val_f1_score: 0.5229 - val_loss: 0.4657 - val_precision: 0.8529
# Epoch 22/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7692 - f1_score: 0.5522 - loss: 0.5170 - precision: 0.6883 - val_accuracy: 0.8012 - val_f1_score: 0.5229 - val_loss: 0.4584 - val_precision: 0.8571
# Epoch 23/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7962 - f1_score: 0.5332 - loss: 0.4994 - precision: 0.7034 - val_accuracy: 0.8199 - val_f1_score: 0.5229 - val_loss: 0.4539 - val_precision: 0.8500
# Epoch 24/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8020 - f1_score: 0.5644 - loss: 0.4829 - precision: 0.7479 - val_accuracy: 0.8323 - val_f1_score: 0.5229 - val_loss: 0.4480 - val_precision: 0.8571
# Epoch 25/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8242 - f1_score: 0.5549 - loss: 0.4511 - precision: 0.7561 - val_accuracy: 0.8261 - val_f1_score: 0.5229 - val_loss: 0.4439 - val_precision: 0.8372
# Epoch 26/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8144 - f1_score: 0.5592 - loss: 0.4476 - precision: 0.7496 - val_accuracy: 0.8199 - val_f1_score: 0.5229 - val_loss: 0.4385 - val_precision: 0.7917
# Epoch 27/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8074 - f1_score: 0.5729 - loss: 0.4779 - precision: 0.7451 - val_accuracy: 0.8261 - val_f1_score: 0.5229 - val_loss: 0.4358 - val_precision: 0.7959
# Epoch 28/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7883 - f1_score: 0.5508 - loss: 0.4813 - precision: 0.7046 - val_accuracy: 0.8075 - val_f1_score: 0.5229 - val_loss: 0.4371 - val_precision: 0.7708
# Epoch 29/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8288 - f1_score: 0.5568 - loss: 0.4197 - precision: 0.7603 - val_accuracy: 0.8075 - val_f1_score: 0.5229 - val_loss: 0.4350 - val_precision: 0.7708
# Epoch 30/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7806 - f1_score: 0.5616 - loss: 0.5255 - precision: 0.7154 - val_accuracy: 0.8199 - val_f1_score: 0.5229 - val_loss: 0.4382 - val_precision: 0.8043
# Epoch 31/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8296 - f1_score: 0.5378 - loss: 0.4107 - precision: 0.7545 - val_accuracy: 0.8261 - val_f1_score: 0.5229 - val_loss: 0.4391 - val_precision: 0.8222
# Epoch 32/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8259 - f1_score: 0.5489 - loss: 0.4232 - precision: 0.7632 - val_accuracy: 0.8323 - val_f1_score: 0.5229 - val_loss: 0.4428 - val_precision: 0.8261
# Epoch 33/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8020 - f1_score: 0.5567 - loss: 0.4657 - precision: 0.7424 - val_accuracy: 0.8137 - val_f1_score: 0.5229 - val_loss: 0.4444 - val_precision: 0.7755
# Epoch 34/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8241 - f1_score: 0.5568 - loss: 0.4507 - precision: 0.7737 - val_accuracy: 0.8199 - val_f1_score: 0.5229 - val_loss: 0.4435 - val_precision: 0.7917
# Epoch 35/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8126 - f1_score: 0.5519 - loss: 0.4420 - precision: 0.7549 - val_accuracy: 0.8261 - val_f1_score: 0.5229 - val_loss: 0.4443 - val_precision: 0.7959
# Epoch 36/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8092 - f1_score: 0.5620 - loss: 0.4724 - precision: 0.7484 - val_accuracy: 0.8137 - val_f1_score: 0.5229 - val_loss: 0.4450 - val_precision: 0.7647
# Epoch 37/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8107 - f1_score: 0.5942 - loss: 0.4733 - precision: 0.7923 - val_accuracy: 0.8012 - val_f1_score: 0.5229 - val_loss: 0.4418 - val_precision: 0.7193
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8285 - f1_score: 0.5862 - loss: 0.4011 - precision: 0.9333
# Test Accuracy: 0.84
# Test Precision: 0.87
# Test F1 Score: 0.57
# Test Loss: 0.38
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_20 (Dense)                │ (None, 160)            │         2,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 160)            │           640 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 104)            │        16,744 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 104)            │           416 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 104)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 48)             │         5,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 48)             │           192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 48)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 112)            │         5,488 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 112)            │           448 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 112)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 1)              │           113 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 92,269 (360.43 KB)
#  Trainable params: 30,473 (119.04 KB)
#  Non-trainable params: 848 (3.31 KB)
#  Optimizer params: 60,948 (238.08 KB)
# None
#
# Iperparametri:
#
#  Epochs: 37
#  Batch Size: 64
#  Learning Rate: 0.0005
#
# Dataset Splits:
#
#  Training Split: 0.90 -> 640 esempi
#  Validation Split: 0.20 -> 160 esempi
#  Test Split: 0.10 -> 90 esempi
#  Totale: 891 esempi

# %%
model.save_model("./saved_models")
