# %%
# %reload_ext autoreload
# %autoreload

import classes.NeuralNetwork as NeuralNetwork
import classes.NeuralNetworkAutoTuning as NeuralNetworkAutoTuning

import importlib

importlib.reload(NeuralNetwork)  # Reload module
importlib.reload(NeuralNetworkAutoTuning)  # Reload module

from classes.NeuralNetwork import TitanicSurvivalModel
from classes.NeuralNetworkAutoTuning import TitanicSurvivalModelAutoTuning

# %%
model = TitanicSurvivalModel(dataset_path = 'data/dataset.csv',
                             epochs = 37,
                             batch_size = 64,
                             test_split = 0.2,
                             validation_split = 0,
                             learning_rate = 5e-4, # 0.0005
                            )

model.start()
model.plot_all()
model.summarize()
# Out:
# ✅ Preprocessing completato!
# Features finali: ['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'Title', 'Has_Cabin', 'Family_Size', 'Is_Alone', 'Age_Group', 'Fare_Group']
# Epoch 1/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.4333 - f1_score: 0.5431 - loss: 0.9746 - precision: 0.3242 - val_accuracy: 0.6398 - val_f1_score: 0.5229 - val_loss: 0.6771 - val_precision: 0.4800
# Epoch 2/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6074 - f1_score: 0.5392 - loss: 0.7637 - precision: 0.4779 - val_accuracy: 0.7453 - val_f1_score: 0.5229 - val_loss: 0.6586 - val_precision: 0.6538
# Epoch 3/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6550 - f1_score: 0.5600 - loss: 0.6687 - precision: 0.5451 - val_accuracy: 0.7578 - val_f1_score: 0.5229 - val_loss: 0.6435 - val_precision: 0.6607
# Epoch 4/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6947 - f1_score: 0.5756 - loss: 0.6113 - precision: 0.5990 - val_accuracy: 0.7578 - val_f1_score: 0.5229 - val_loss: 0.6321 - val_precision: 0.6731
# Epoch 5/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7085 - f1_score: 0.5796 - loss: 0.6184 - precision: 0.6207 - val_accuracy: 0.7578 - val_f1_score: 0.5229 - val_loss: 0.6238 - val_precision: 0.6800
# Epoch 6/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7079 - f1_score: 0.5417 - loss: 0.5758 - precision: 0.5893 - val_accuracy: 0.8012 - val_f1_score: 0.5229 - val_loss: 0.6118 - val_precision: 0.7778
# Epoch 7/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7260 - f1_score: 0.5652 - loss: 0.6604 - precision: 0.6308 - val_accuracy: 0.8075 - val_f1_score: 0.5229 - val_loss: 0.6015 - val_precision: 0.7955
# Epoch 8/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7179 - f1_score: 0.5643 - loss: 0.5964 - precision: 0.6184 - val_accuracy: 0.8012 - val_f1_score: 0.5229 - val_loss: 0.5896 - val_precision: 0.8205
# Epoch 9/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7208 - f1_score: 0.5550 - loss: 0.5841 - precision: 0.6154 - val_accuracy: 0.8012 - val_f1_score: 0.5229 - val_loss: 0.5737 - val_precision: 0.8378
# Epoch 10/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7778 - f1_score: 0.5655 - loss: 0.5203 - precision: 0.6940 - val_accuracy: 0.8012 - val_f1_score: 0.5229 - val_loss: 0.5589 - val_precision: 0.8378
# Epoch 11/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7792 - f1_score: 0.5495 - loss: 0.5214 - precision: 0.6820 - val_accuracy: 0.7950 - val_f1_score: 0.5229 - val_loss: 0.5446 - val_precision: 0.8333
# Epoch 12/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7551 - f1_score: 0.5305 - loss: 0.5561 - precision: 0.6373 - val_accuracy: 0.7950 - val_f1_score: 0.5229 - val_loss: 0.5352 - val_precision: 0.8158
# Epoch 13/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7668 - f1_score: 0.5557 - loss: 0.5003 - precision: 0.6880 - val_accuracy: 0.8075 - val_f1_score: 0.5229 - val_loss: 0.5257 - val_precision: 0.8250
# Epoch 14/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7602 - f1_score: 0.5378 - loss: 0.5321 - precision: 0.6461 - val_accuracy: 0.8075 - val_f1_score: 0.5229 - val_loss: 0.5167 - val_precision: 0.8250
# Epoch 15/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7839 - f1_score: 0.5609 - loss: 0.5018 - precision: 0.7147 - val_accuracy: 0.8012 - val_f1_score: 0.5229 - val_loss: 0.5067 - val_precision: 0.8205
# Epoch 16/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7538 - f1_score: 0.5185 - loss: 0.5303 - precision: 0.6221 - val_accuracy: 0.8137 - val_f1_score: 0.5229 - val_loss: 0.4993 - val_precision: 0.8293
# Epoch 17/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7577 - f1_score: 0.5705 - loss: 0.5036 - precision: 0.6788 - val_accuracy: 0.8137 - val_f1_score: 0.5229 - val_loss: 0.4902 - val_precision: 0.8140
# Epoch 18/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8139 - f1_score: 0.5633 - loss: 0.4393 - precision: 0.7395 - val_accuracy: 0.8261 - val_f1_score: 0.5229 - val_loss: 0.4814 - val_precision: 0.7843
# Epoch 19/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7884 - f1_score: 0.5604 - loss: 0.4753 - precision: 0.7070 - val_accuracy: 0.8261 - val_f1_score: 0.5229 - val_loss: 0.4746 - val_precision: 0.7843
# Epoch 20/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7980 - f1_score: 0.5839 - loss: 0.4705 - precision: 0.7381 - val_accuracy: 0.8323 - val_f1_score: 0.5229 - val_loss: 0.4671 - val_precision: 0.8000
# Epoch 21/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8086 - f1_score: 0.5836 - loss: 0.4505 - precision: 0.7716 - val_accuracy: 0.8199 - val_f1_score: 0.5229 - val_loss: 0.4588 - val_precision: 0.7917
# Epoch 22/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7903 - f1_score: 0.5802 - loss: 0.4899 - precision: 0.7385 - val_accuracy: 0.8199 - val_f1_score: 0.5229 - val_loss: 0.4513 - val_precision: 0.7917
# Epoch 23/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7876 - f1_score: 0.5745 - loss: 0.4850 - precision: 0.7536 - val_accuracy: 0.8385 - val_f1_score: 0.5229 - val_loss: 0.4477 - val_precision: 0.8163
# Epoch 24/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7867 - f1_score: 0.5242 - loss: 0.4787 - precision: 0.6735 - val_accuracy: 0.8385 - val_f1_score: 0.5229 - val_loss: 0.4414 - val_precision: 0.8163
# Epoch 25/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7873 - f1_score: 0.5766 - loss: 0.4765 - precision: 0.7362 - val_accuracy: 0.8323 - val_f1_score: 0.5229 - val_loss: 0.4364 - val_precision: 0.8000
# Epoch 26/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7693 - f1_score: 0.5465 - loss: 0.4958 - precision: 0.6790 - val_accuracy: 0.8385 - val_f1_score: 0.5229 - val_loss: 0.4294 - val_precision: 0.8163
# Epoch 27/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7888 - f1_score: 0.5746 - loss: 0.4936 - precision: 0.7377 - val_accuracy: 0.8385 - val_f1_score: 0.5229 - val_loss: 0.4265 - val_precision: 0.8039
# Epoch 28/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8143 - f1_score: 0.5555 - loss: 0.4442 - precision: 0.7303 - val_accuracy: 0.8385 - val_f1_score: 0.5229 - val_loss: 0.4216 - val_precision: 0.8039
# Epoch 29/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7933 - f1_score: 0.5517 - loss: 0.5277 - precision: 0.7083 - val_accuracy: 0.8385 - val_f1_score: 0.5229 - val_loss: 0.4214 - val_precision: 0.8039
# Epoch 30/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7886 - f1_score: 0.5536 - loss: 0.4629 - precision: 0.7201 - val_accuracy: 0.8323 - val_f1_score: 0.5229 - val_loss: 0.4207 - val_precision: 0.8000
# Epoch 31/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7786 - f1_score: 0.5445 - loss: 0.4665 - precision: 0.6952 - val_accuracy: 0.8323 - val_f1_score: 0.5229 - val_loss: 0.4192 - val_precision: 0.8125
# Epoch 32/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8094 - f1_score: 0.5607 - loss: 0.4790 - precision: 0.7501 - val_accuracy: 0.8323 - val_f1_score: 0.5229 - val_loss: 0.4198 - val_precision: 0.8125
# Epoch 33/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8174 - f1_score: 0.5586 - loss: 0.4417 - precision: 0.7550 - val_accuracy: 0.8261 - val_f1_score: 0.5229 - val_loss: 0.4211 - val_precision: 0.7959
# Epoch 34/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8124 - f1_score: 0.5129 - loss: 0.4392 - precision: 0.7001 - val_accuracy: 0.8261 - val_f1_score: 0.5229 - val_loss: 0.4197 - val_precision: 0.7736
# Epoch 35/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8044 - f1_score: 0.5739 - loss: 0.4772 - precision: 0.7651 - val_accuracy: 0.8261 - val_f1_score: 0.5229 - val_loss: 0.4212 - val_precision: 0.7544
# Epoch 36/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7980 - f1_score: 0.5836 - loss: 0.4635 - precision: 0.7609 - val_accuracy: 0.8261 - val_f1_score: 0.5229 - val_loss: 0.4234 - val_precision: 0.7544
# Epoch 37/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8209 - f1_score: 0.5672 - loss: 0.4353 - precision: 0.7687 - val_accuracy: 0.8447 - val_f1_score: 0.5229 - val_loss: 0.4250 - val_precision: 0.7857
# Epoch 38/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8009 - f1_score: 0.5401 - loss: 0.4519 - precision: 0.7083 - val_accuracy: 0.8447 - val_f1_score: 0.5229 - val_loss: 0.4242 - val_precision: 0.7963
# Epoch 39/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8407 - f1_score: 0.5717 - loss: 0.3964 - precision: 0.8037 - val_accuracy: 0.8323 - val_f1_score: 0.5229 - val_loss: 0.4239 - val_precision: 0.7679
# Epoch 40/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8239 - f1_score: 0.5560 - loss: 0.4124 - precision: 0.7664 - val_accuracy: 0.8385 - val_f1_score: 0.5229 - val_loss: 0.4264 - val_precision: 0.7818
# Epoch 41/300
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8211 - f1_score: 0.5724 - loss: 0.4448 - precision: 0.7753 - val_accuracy: 0.8385 - val_f1_score: 0.5229 - val_loss: 0.4269 - val_precision: 0.7925
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8575 - f1_score: 0.5862 - loss: 0.3851 - precision: 0.9024
# Test Accuracy: 0.86
# Test Precision: 0.83
# Test F1 Score: 0.57
# Test Loss: 0.39
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_30 (Dense)                │ (None, 160)            │         2,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_24          │ (None, 160)            │           640 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_24 (Dropout)            │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 104)            │        16,744 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_25          │ (None, 104)            │           416 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_25 (Dropout)            │ (None, 104)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ (None, 48)             │         5,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_26          │ (None, 48)             │           192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_26 (Dropout)            │ (None, 48)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ (None, 112)            │         5,488 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_27          │ (None, 112)            │           448 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_27 (Dropout)            │ (None, 112)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 1)              │           113 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 92,269 (360.43 KB)
#  Trainable params: 30,473 (119.04 KB)
#  Non-trainable params: 848 (3.31 KB)
#  Optimizer params: 60,948 (238.08 KB)
# None
#
# Iperparametri:
#
#  Epochs: 300
#  Batch Size: 64
#  Learning Rate: 0.0005
#
# Dataset Splits:
#
#  Training Split: 0.90 -> 640 esempi
#  Validation Split: 0.20 -> 160 esempi
#  Test Split: 0.10 -> 90 esempi
#  Totale: 891 esempi

# %%
# model.save_model("./saved_models")
