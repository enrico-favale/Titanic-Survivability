# %%
# %reload_ext autoreload
# %autoreload

import classes.NeuralNetwork as NeuralNetwork
import classes.NeuralNetworkAutoTuning as NeuralNetworkAutoTuning

import importlib

importlib.reload(NeuralNetwork)  # Reload module
importlib.reload(NeuralNetworkAutoTuning)  # Reload module

from classes.NeuralNetwork import TitanicSurvivalModel
from classes.NeuralNetworkAutoTuning import TitanicSurvivalModelAutoTuning

# %%
model = TitanicSurvivalModel(dataset_path = 'data/dataset.csv',
                             epochs = 37,
                             batch_size = 64,
                             test_split = 0.2,
                             validation_split = 0,
                             learning_rate = 5e-4, # 0.0005
                            )

model.start()
model.plot_all()
model.summarize()
# Out:
# ✅ Preprocessing completato!
# Features finali: ['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'Title', 'Has_Cabin', 'Family_Size', 'Is_Alone', 'Age_Group', 'Fare_Group']
# Epoch 1/37
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.5513 - f1_score: 0.5356 - loss: 0.8539 - precision: 0.4166
# Epoch 2/37
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6381 - f1_score: 0.5333 - loss: 0.7233 - precision: 0.5020
# Epoch 3/37
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6534 - f1_score: 0.5390 - loss: 0.6926 - precision: 0.5243
# Epoch 4/37
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7245 - f1_score: 0.5770 - loss: 0.6035 - precision: 0.6408
# Epoch 5/37
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7063 - f1_score: 0.5387 - loss: 0.5989 - precision: 0.5810
# Epoch 6/37
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6968 - f1_score: 0.5407 - loss: 0.5994 - precision: 0.5768
# Epoch 7/37
# ...

# %%
# model.save_model("./saved_models")
