# %%
# %reload_ext autoreload
# %autoreload

import models.NeuralNetwork as NeuralNetwork
import models.NeuralNetworkAutoTuning as NeuralNetworkAutoTuning

import importlib

importlib.reload(NeuralNetwork)  # Reload module
importlib.reload(NeuralNetworkAutoTuning)  # Reload module

from models.NeuralNetwork import TitanicSurvivalModel
from models.NeuralNetworkAutoTuning import TitanicSurvivalModelAutoTuning
# Out:
# 2025-05-26 14:23:24.576565: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748262204.597654 2796203 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748262204.604137 2796203 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1748262204.620950 2796203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748262204.620968 2796203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748262204.620970 2796203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748262204.620972 2796203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-26 14:23:24.626544: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/enrico/miniconda3/envs/titanic-env/lib/python3.10/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
model = TitanicSurvivalModel(dataset_path = 'data/dataset.csv',
                             epochs = 37,
                             batch_size = 64,
                             test_split = 0.1,
                             validation_split = 0.2,
                             learning_rate = 5e-4,
                            )

model.start()
model.plot_all()
model.summarize()
# Out:
# ✅ Preprocessing completato!
# Features finali: ['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'Title', 'Has_Cabin', 'Family_Size', 'Is_Alone', 'Age_Group', 'Fare_Group']
# Epoch 1/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.5851 - f1_score: 0.5848 - loss: 0.8792 - precision: 0.4995 - val_accuracy: 0.6957 - val_f1_score: 0.5229 - val_loss: 0.6823 - val_precision: 0.5455
# Epoch 2/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6330 - f1_score: 0.5340 - loss: 0.7033 - precision: 0.4975 - val_accuracy: 0.7205 - val_f1_score: 0.5229 - val_loss: 0.6749 - val_precision: 0.5732
# Epoch 3/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6425 - f1_score: 0.5869 - loss: 0.7248 - precision: 0.5608 - val_accuracy: 0.7516 - val_f1_score: 0.5229 - val_loss: 0.6701 - val_precision: 0.6133
# Epoch 4/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6990 - f1_score: 0.5701 - loss: 0.6309 - precision: 0.6041 - val_accuracy: 0.7516 - val_f1_score: 0.5229 - val_loss: 0.6619 - val_precision: 0.6197
# Epoch 5/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6797 - f1_score: 0.5616 - loss: 0.6592 - precision: 0.5721 - val_accuracy: 0.7640 - val_f1_score: 0.5229 - val_loss: 0.6488 - val_precision: 0.6557
# Epoch 6/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7150 - f1_score: 0.5783 - loss: 0.6264 - precision: 0.6331 - val_accuracy: 0.7640 - val_f1_score: 0.5229 - val_loss: 0.6385 - val_precision: 0.6557
# Epoch 7/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7243 - f1_score: 0.5262 - loss: 0.5665 - precision: 0.5916 - val_accuracy: 0.7640 - val_f1_score: 0.5229 - val_loss: 0.6280 - val_precision: 0.6939
# Epoch 8/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7714 - f1_score: 0.5778 - loss: 0.5442 - precision: 0.7018 - val_accuracy: 0.7640 - val_f1_score: 0.5229 - val_loss: 0.6169 - val_precision: 0.6939
# Epoch 9/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7599 - f1_score: 0.6005 - loss: 0.5481 - precision: 0.7198 - val_accuracy: 0.8012 - val_f1_score: 0.5229 - val_loss: 0.6039 - val_precision: 0.7273
# Epoch 10/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7581 - f1_score: 0.5678 - loss: 0.5836 - precision: 0.6778 - val_accuracy: 0.8012 - val_f1_score: 0.5229 - val_loss: 0.5909 - val_precision: 0.7273
# Epoch 11/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7484 - f1_score: 0.5339 - loss: 0.5648 - precision: 0.6271 - val_accuracy: 0.8075 - val_f1_score: 0.5229 - val_loss: 0.5776 - val_precision: 0.7407
# Epoch 12/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7823 - f1_score: 0.5568 - loss: 0.4940 - precision: 0.6885 - val_accuracy: 0.8137 - val_f1_score: 0.5229 - val_loss: 0.5649 - val_precision: 0.7547
# Epoch 13/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7689 - f1_score: 0.5802 - loss: 0.5260 - precision: 0.7046 - val_accuracy: 0.7950 - val_f1_score: 0.5229 - val_loss: 0.5512 - val_precision: 0.7143
# Epoch 14/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7444 - f1_score: 0.5432 - loss: 0.5477 - precision: 0.6465 - val_accuracy: 0.8075 - val_f1_score: 0.5229 - val_loss: 0.5427 - val_precision: 0.7241
# Epoch 15/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8187 - f1_score: 0.5470 - loss: 0.4692 - precision: 0.7277 - val_accuracy: 0.8137 - val_f1_score: 0.5229 - val_loss: 0.5360 - val_precision: 0.7368
# Epoch 16/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7712 - f1_score: 0.5689 - loss: 0.5071 - precision: 0.7030 - val_accuracy: 0.8137 - val_f1_score: 0.5229 - val_loss: 0.5273 - val_precision: 0.7368
# Epoch 17/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7750 - f1_score: 0.5842 - loss: 0.4976 - precision: 0.7209 - val_accuracy: 0.8137 - val_f1_score: 0.5229 - val_loss: 0.5194 - val_precision: 0.7455
# Epoch 18/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7801 - f1_score: 0.5741 - loss: 0.5109 - precision: 0.7161 - val_accuracy: 0.8137 - val_f1_score: 0.5229 - val_loss: 0.5112 - val_precision: 0.7547
# Epoch 19/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8169 - f1_score: 0.5908 - loss: 0.4829 - precision: 0.7962 - val_accuracy: 0.8075 - val_f1_score: 0.5229 - val_loss: 0.4991 - val_precision: 0.7500
# Epoch 20/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7527 - f1_score: 0.5092 - loss: 0.5549 - precision: 0.6165 - val_accuracy: 0.8261 - val_f1_score: 0.5229 - val_loss: 0.4902 - val_precision: 0.7843
# Epoch 21/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7908 - f1_score: 0.5426 - loss: 0.4947 - precision: 0.7016 - val_accuracy: 0.8199 - val_f1_score: 0.5229 - val_loss: 0.4823 - val_precision: 0.7800
# Epoch 22/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8045 - f1_score: 0.5611 - loss: 0.5089 - precision: 0.7286 - val_accuracy: 0.8199 - val_f1_score: 0.5229 - val_loss: 0.4729 - val_precision: 0.7800
# Epoch 23/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7748 - f1_score: 0.5378 - loss: 0.5269 - precision: 0.6864 - val_accuracy: 0.8137 - val_f1_score: 0.5229 - val_loss: 0.4655 - val_precision: 0.7755
# Epoch 24/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8151 - f1_score: 0.5562 - loss: 0.4547 - precision: 0.7474 - val_accuracy: 0.8075 - val_f1_score: 0.5229 - val_loss: 0.4605 - val_precision: 0.7500
# Epoch 25/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7917 - f1_score: 0.5830 - loss: 0.5042 - precision: 0.7596 - val_accuracy: 0.8012 - val_f1_score: 0.5229 - val_loss: 0.4572 - val_precision: 0.7451
# Epoch 26/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7985 - f1_score: 0.5563 - loss: 0.4742 - precision: 0.7328 - val_accuracy: 0.8012 - val_f1_score: 0.5229 - val_loss: 0.4555 - val_precision: 0.7551
# Epoch 27/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7960 - f1_score: 0.5714 - loss: 0.4771 - precision: 0.7373 - val_accuracy: 0.8075 - val_f1_score: 0.5229 - val_loss: 0.4551 - val_precision: 0.7500
# Epoch 28/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7603 - f1_score: 0.5495 - loss: 0.5062 - precision: 0.6714 - val_accuracy: 0.8012 - val_f1_score: 0.5229 - val_loss: 0.4496 - val_precision: 0.7551
# Epoch 29/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8096 - f1_score: 0.5467 - loss: 0.4688 - precision: 0.7388 - val_accuracy: 0.8075 - val_f1_score: 0.5229 - val_loss: 0.4421 - val_precision: 0.7600
# Epoch 30/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8142 - f1_score: 0.5462 - loss: 0.4416 - precision: 0.7363 - val_accuracy: 0.8012 - val_f1_score: 0.5229 - val_loss: 0.4391 - val_precision: 0.7551
# Epoch 31/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8151 - f1_score: 0.5580 - loss: 0.4564 - precision: 0.7611 - val_accuracy: 0.8075 - val_f1_score: 0.5229 - val_loss: 0.4391 - val_precision: 0.7500
# Epoch 32/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7772 - f1_score: 0.5697 - loss: 0.5147 - precision: 0.7197 - val_accuracy: 0.8137 - val_f1_score: 0.5229 - val_loss: 0.4372 - val_precision: 0.7547
# Epoch 33/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8155 - f1_score: 0.5581 - loss: 0.4626 - precision: 0.7821 - val_accuracy: 0.8137 - val_f1_score: 0.5229 - val_loss: 0.4360 - val_precision: 0.7547
# Epoch 34/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8274 - f1_score: 0.5828 - loss: 0.4763 - precision: 0.7959 - val_accuracy: 0.8137 - val_f1_score: 0.5229 - val_loss: 0.4313 - val_precision: 0.7547
# Epoch 35/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7781 - f1_score: 0.5602 - loss: 0.4843 - precision: 0.7054 - val_accuracy: 0.8012 - val_f1_score: 0.5229 - val_loss: 0.4301 - val_precision: 0.7273
# Epoch 36/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7939 - f1_score: 0.5419 - loss: 0.4888 - precision: 0.7110 - val_accuracy: 0.7888 - val_f1_score: 0.5229 - val_loss: 0.4312 - val_precision: 0.7170
# Epoch 37/37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8104 - f1_score: 0.5490 - loss: 0.4547 - precision: 0.7327 - val_accuracy: 0.8075 - val_f1_score: 0.5229 - val_loss: 0.4331 - val_precision: 0.7407
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8575 - f1_score: 0.5862 - loss: 0.3937 - precision: 0.8447
# Test Accuracy: 0.86
# Test Precision: 0.79
# Test F1 Score: 0.57
# Test Loss: 0.39
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7829f1395900> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/stepWARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7829f1395900> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                │ (None, 160)            │         2,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 160)            │           640 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 104)            │        16,744 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 104)            │           416 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 104)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 48)             │         5,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 48)             │           192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 48)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 112)            │         5,488 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 112)            │           448 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 112)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │           113 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 92,269 (360.43 KB)
#  Trainable params: 30,473 (119.04 KB)
#  Non-trainable params: 848 (3.31 KB)
#  Optimizer params: 60,948 (238.08 KB)
# None
#
# Iperparametri:
#
#  Epochs: 37
#  Batch Size: 64
#  Learning Rate: 0.0005
#
# Dataset Splits:
#
#  Training Split: 0.90 -> 640 esempi
#  Validation Split: 0.20 -> 160 esempi
#  Test Split: 0.10 -> 90 esempi
#  Totale: 891 esempi

# %%
model.save_model("./saved_models")
